# %% [markdown]
# <a href="https://colab.research.google.com/github/elaineliu05/DS3021_MurderProject/blob/main/Offender_Demographics_Prediction_in_VA_Unsolved_Cases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Murder Mystery - Who are the <b>suspects on the run</b> the unsolved cases in the State of Virginia

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('SHR65_23 (2).csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894636 entries, 0 to 894635
# Data columns (total 30 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            894636 non-null  object
#  1   CNTYFIPS      894636 non-null  object
#  2   Ori           894636 non-null  object
#  3   State         894636 non-null  object
#  4   Agency        894636 non-null  object
#  5   Agentype      894636 non-null  object
#  6   Source        894636 non-null  object
#  7   Solved        894636 non-null  object
#  8   Year          894636 non-null  int64
#  9   Month         894636 non-null  object
#  10  Incident      894636 non-null  int64
#  11  ActionType    894636 non-null  object
#  12  Homicide      894636 non-null  object
#  13  Situation     894636 non-null  object
#  14  VicAge        894636 non-null  int64
#  15  VicSex        894636 non-null  object
#  16  VicRace       894636 non-null  object
#  17  VicEthnic     894636 non-null  object
#  18  OffAge        894636 non-null  int64
#  19  OffSex        894636 non-null  object
#  20  OffRace       894636 non-null  object
#  21  OffEthnic     894636 non-null  object
#  22  Weapon        894636 non-null  object
#  23  Relationship  894636 non-null  object
#  24  Circumstance  894636 non-null  object
#  25  Subcircum     34750 non-null   object
#  26  VicCount      894636 non-null  int64
#  27  OffCount      894636 non-null  int64
#  28  FileDate      877561 non-null  float64
#  29  MSA           894636 non-null  object
# dtypes: float64(1), int64(6), object(23)
# memory usage: 204.8+ MB

# %%
df.head(5)
# Out:
#                  ID       CNTYFIPS      Ori   State     Agency  \
# 0  197603001AK00101  Anchorage, AK  AK00101  Alaska  Anchorage
# 1  197604001AK00101  Anchorage, AK  AK00101  Alaska  Anchorage
# 2  197606001AK00101  Anchorage, AK  AK00101  Alaska  Anchorage
# 3  197606002AK00101  Anchorage, AK  AK00101  Alaska  Anchorage
# 4  197607001AK00101  Anchorage, AK  AK00101  Alaska  Anchorage
#
#            Agentype Source Solved  Year  Month  ...  \
# 0  Municipal police    FBI    Yes  1976  March  ...
# 1  Municipal police    FBI    Yes  1976  April  ...
# 2  Municipal police    FBI    Yes  1976   June  ...
# 3  Municipal police    FBI    Yes  1976   June  ...
# 4  Municipal police    FBI    Yes  1976   July  ...
#
#                              OffRace                OffEthnic  \
# 0                              Black  Unknown or not reported
# 1                              White  Unknown or not reported
# 2                              Black  Unknown or not reported
# 3                              White  Unknown or not reported
# 4  American Indian or Alaskan Native  Unknown or not reported
#
#                             Weapon                 Relationship  \
# 0  Handgun - pistol, revolver, etc  Relationship not determined
# 1  Handgun - pistol, revolver, etc                   Girlfriend
# 2  Handgun - pistol, revolver, etc                     Stranger
# 3  Handgun - pistol, revolver, etc      Other - known to victim
# 4      Knife or cutting instrument                      Brother
#
#       Circumstance Subcircum VicCount OffCount  FileDate            MSA
# 0  Other arguments       NaN        0        0   30180.0  Anchorage, AK
# 1  Other arguments       NaN        0        0   30180.0  Anchorage, AK
# 2            Other       NaN        0        0   30180.0  Anchorage, AK
# 3  Other arguments       NaN        0        0   30180.0  Anchorage, AK
# 4  Other arguments       NaN        0        0   30180.0  Anchorage, AK
#
# [5 rows x 30 columns]

# %% [markdown]
# # Data Cleaning - Renaming, dropping null value columns, and dropping useless columns

# %%
rename_columns = {
    'CNTYFIPS': 'CountyFIPS',
    'Ori': 'OriginatingAgencyID',
    'Agency': 'AgencyName',
    'Agentype': 'AgencyType',
    'Source': 'SourceAgency',
    'Solved': 'SolvedStatus',
    'Year': 'YearReported',
    'Month': 'MonthReported',
    'Incident': 'IncidentID',
    'ActionType': 'ReportActionType',
    'Homicide': 'HomicideType',
    'Situation': 'CrimeSituation',
    'VicAge': 'VictimAge',
    'VicSex': 'VictimSex',
    'VicRace': 'VictimRace',
    'VicEthnic': 'VictimEthnicity',
    'OffAge': 'OffenderAge',
    'OffSex': 'OffenderSex',
    'OffRace': 'OffenderRace',
    'OffEthnic': 'OffenderEthnicity',
    'Weapon': 'WeaponUsed',
    'Relationship': 'VictimOffenderRelationship',
    'Circumstance': 'CrimeCircumstance',
    'Subcircum': 'CrimeSubCircumstance',
    'VicCount': 'AdditionalVictimCount',
    'OffCount': 'AdditionalOffenderCount',
    'FileDate': 'RecordFileDate',
    'MSA': 'MetropolitanArea'
}

df.rename(columns=rename_columns, inplace=True)

# Drop useless or high-null columns
columns_to_drop = ['CrimeSubCircumstance', 'OriginatingAgencyID', 'SourceAgency','RecordFileDate', 'ID', 'OffenderEthnicity']
df.drop(columns=columns_to_drop, inplace=True)

df
# Out:
#            CountyFIPS    State         AgencyName        AgencyType  \
# 0       Anchorage, AK   Alaska          Anchorage  Municipal police
# 1       Anchorage, AK   Alaska          Anchorage  Municipal police
# 2       Anchorage, AK   Alaska          Anchorage  Municipal police
# 3       Anchorage, AK   Alaska          Anchorage  Municipal police
# 4       Anchorage, AK   Alaska          Anchorage  Municipal police
# ...               ...      ...                ...               ...
# 894631    Fremont, WY  Wyoming  Wind River Agency            Tribal
# 894632    Fremont, WY  Wyoming  Wind River Agency            Tribal
# 894633    Fremont, WY  Wyoming  Wind River Agency            Tribal
# 894634    Fremont, WY  Wyoming  Wind River Agency            Tribal
# 894635    Fremont, WY  Wyoming  Wind River Agency            Tribal
#
#        SolvedStatus  YearReported MonthReported  IncidentID ReportActionType  \
# 0               Yes          1976         March           1    Normal update
# 1               Yes          1976         April           1    Normal update
# 2               Yes          1976          June           1    Normal update
# 3               Yes          1976          June           2    Normal update
# 4               Yes          1976          July           1    Normal update
# ...             ...           ...           ...         ...              ...
# 894631           No          2018        August           1    Normal update
# 894632          Yes          2019        August           1    Normal update
# 894633          Yes          2023         March           2    Normal update
# 894634          Yes          2023         March           1    Normal update
# 894635          Yes          2023        August           1    Normal update
#
#                                  HomicideType  ...          VictimEthnicity  \
# 0       Murder and non-negligent manslaughter  ...  Unknown or not reported
# 1       Murder and non-negligent manslaughter  ...  Unknown or not reported
# 2       Murder and non-negligent manslaughter  ...  Unknown or not reported
# 3       Murder and non-negligent manslaughter  ...  Unknown or not reported
# 4       Murder and non-negligent manslaughter  ...  Unknown or not reported
# ...                                       ...  ...                      ...
# 894631  Murder and non-negligent manslaughter  ...   Not of Hispanic origin
# 894632  Murder and non-negligent manslaughter  ...   Not of Hispanic origin
# 894633  Murder and non-negligent manslaughter  ...   Not of Hispanic origin
# 894634  Murder and non-negligent manslaughter  ...   Not of Hispanic origin
# 894635  Murder and non-negligent manslaughter  ...   Not of Hispanic origin
#
#         OffenderAge OffenderSex                       OffenderRace  \
# 0                68        Male                              Black
# 1                44        Male                              White
# 2                27        Male                              Black
# 3                34        Male                              White
# 4                37      Female  American Indian or Alaskan Native
# ...             ...         ...                                ...
# 894631          999     Unknown                            Unknown
# 894632           30        Male  American Indian or Alaskan Native
# 894633           33        Male  American Indian or Alaskan Native
# 894634           29        Male  American Indian or Alaskan Native
# 894635           59        Male  American Indian or Alaskan Native
#
#                              WeaponUsed   VictimOffenderRelationship  \
# 0       Handgun - pistol, revolver, etc  Relationship not determined
# 1       Handgun - pistol, revolver, etc                   Girlfriend
# 2       Handgun - pistol, revolver, etc                     Stranger
# 3       Handgun - pistol, revolver, etc      Other - known to victim
# 4           Knife or cutting instrument                      Brother
# ...                                 ...                          ...
# 894631                          Shotgun      Other - known to victim
# 894632         Firearm, type not stated                 Acquaintance
# 894633         Firearm, type not stated      Other - known to victim
# 894634            Other or type unknown  Relationship not determined
# 894635  Handgun - pistol, revolver, etc      Other - known to victim
#
#                  CrimeCircumstance AdditionalVictimCount  \
# 0                  Other arguments                     0
# 1                  Other arguments                     0
# 2                            Other                     0
# 3                  Other arguments                     0
# 4                  Other arguments                     0
# ...                            ...                   ...
# 894631          Narcotic drug laws                     0
# 894632                       Other                     0
# 894633  Circumstances undetermined                     0
# 894634                       Other                     0
# 894635             Other arguments                     0
#
#        AdditionalOffenderCount MetropolitanArea
# 0                            0    Anchorage, AK
# 1                            0    Anchorage, AK
# 2                            0    Anchorage, AK
# 3                            0    Anchorage, AK
# 4                            0    Anchorage, AK
# ...                        ...              ...
# 894631                       0    Rural Wyoming
# 894632                       0    Rural Wyoming
# 894633                       0    Rural Wyoming
# 894634                       0    Rural Wyoming
# 894635                       0    Rural Wyoming
#
# [894636 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# CountyFIPS                    0
# State                         0
# AgencyName                    0
# AgencyType                    0
# SolvedStatus                  0
# YearReported                  0
# MonthReported                 0
# IncidentID                    0
# ReportActionType              0
# HomicideType                  0
# CrimeSituation                0
# VictimAge                     0
# VictimSex                     0
# VictimRace                    0
# VictimEthnicity               0
# OffenderAge                   0
# OffenderSex                   0
# OffenderRace                  0
# WeaponUsed                    0
# VictimOffenderRelationship    0
# CrimeCircumstance             0
# AdditionalVictimCount         0
# AdditionalOffenderCount       0
# MetropolitanArea              0
# dtype: int64

# %%
print(df['CrimeCircumstance'].value_counts(), '\n')
print(df['CrimeSituation'].value_counts())
# Out:
# CrimeCircumstance
# Circumstances undetermined              249629
# Other arguments                         226885
# Other                                   115227
# Robbery                                  62407
# Narcotic drug laws                       32289
# Other - not specified                    31591
# Juvenile gang killings                   25999
# Felon killed by police                   19007
# Brawl due to influence of alcohol        16340
# Argument over money or property          16015
# Felon killed by private citizen          15758
# All suspected felony type                13862
# Lovers triangle                          12707
# All other manslaughter by negligence     12214
# Burglary                                  6910
# Gangland killings                         6860
# Brawl due to influence of narcotics       5257
# Arson                                     5162
# Other negligent handling of gun           4680
# Rape                                      4281
# Children playing with gun                 1675
# Motor vehicle theft                       1639
# Other sex offense                         1487
# Institutional killings                    1421
# Child killed by babysitter                1359
# Gambling                                  1100
# Larceny                                   1003
# Prostitution and commercialized vice       657
# Sniper attack                              558
# Victim shot in hunting accident            453
# Gun-cleaning death - other than self       188
# Abortion                                    14
# 31                                           1
# 30                                           1
# Name: count, dtype: int64
#
# CrimeSituation
# Single victim/single offender           489422
# Single victim/unknown offender(s)       231623
# Single victim/multiple offenders         95370
# Multiple victims/single offender         44596
# Multiple victims/unknown offender(s)     19904
# Multiple victims/multiple offenders      13721
# Name: count, dtype: int64

# %% [markdown]
# # Cleaning outliers in the age variable

# %%
# cleaning the age variable
sns.kdeplot(df['VictimAge'])
sns.kdeplot(df['OffenderAge'])
plt.show()

# %%
df = df[df['VictimAge'] != 999]
df = df[df['OffenderAge'] != 999]
sns.kdeplot(df['VictimAge'], color='green', label='Victim Age')
sns.kdeplot(df['OffenderAge'], color='red', label='Offender Age')
plt.legend(bbox_to_anchor=(1, 1))
plt.xlabel('Age')
plt.ylabel('Density')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# # Find out about what's missing in the unsolved cases in the demographic dataset

# %% [markdown]
# ## First by examining the unsolved cases

# %%
df_unsolved = df[df['SolvedStatus'] == 'No']
df_unsolved.head(5)
# Out:
#               CountyFIPS    State             AgencyName        AgencyType  \
# 673        Anchorage, AK   Alaska              Anchorage  Municipal police
# 1403  Aleutians West, AK   Alaska               Unalaska  Municipal police
# 2309       Anchorage, AK   Alaska  Alaska State Troopers  Primary state LE
# 4482       Jefferson, AL  Alabama             Birmingham  Municipal police
# 4625       Jefferson, AL  Alabama             Birmingham  Municipal police
#
#      SolvedStatus  YearReported MonthReported  IncidentID ReportActionType  \
# 673            No          2012          July           1    Normal update
# 1403           No          2012      February           1    Normal update
# 2309           No          2019      December           2    Normal update
# 4482           No          1989      November           5       Adjustment
# 4625           No          1991       January           5    Normal update
#
#                                HomicideType  ...          VictimEthnicity  \
# 673   Murder and non-negligent manslaughter  ...  Unknown or not reported
# 1403  Murder and non-negligent manslaughter  ...  Unknown or not reported
# 2309  Murder and non-negligent manslaughter  ...  Unknown or not reported
# 4482  Murder and non-negligent manslaughter  ...  Unknown or not reported
# 4625  Murder and non-negligent manslaughter  ...  Unknown or not reported
#
#       OffenderAge OffenderSex OffenderRace  \
# 673            28     Unknown      Unknown
# 1403           34     Unknown      Unknown
# 2309           99     Unknown      Unknown
# 4482           20     Unknown      Unknown
# 4625           24     Unknown      Unknown
#
#                               WeaponUsed   VictimOffenderRelationship  \
# 673             Firearm, type not stated                     Stranger
# 1403  Personal weapons, includes beating                 Acquaintance
# 2309            Firearm, type not stated  Relationship not determined
# 4482     Handgun - pistol, revolver, etc  Relationship not determined
# 4625     Handgun - pistol, revolver, etc                     Stranger
#
#                     CrimeCircumstance AdditionalVictimCount  \
# 673   Felon killed by private citizen                     0
# 1403                  Other arguments                     0
# 2309       Circumstances undetermined                     0
# 4482                            Other                     0
# 4625       Circumstances undetermined                     0
#
#      AdditionalOffenderCount       MetropolitanArea
# 673                        1          Anchorage, AK
# 1403                       1           Rural Alaska
# 2309                       0          Anchorage, AK
# 4482                       1  Birmingham-Hoover, AL
# 4625                       1  Birmingham-Hoover, AL
#
# [5 rows x 24 columns]

# %%
sex_counts = df_unsolved['OffenderSex'].value_counts().reset_index()
sex_counts.columns = ['OffenderSex', 'CaseCount']
race_counts = df_unsolved['OffenderRace'].value_counts().reset_index()
race_counts.columns = ['OffenderRace', 'CaseCount']

vic_sex_counts = df_unsolved['VictimSex'].value_counts().reset_index()
vic_sex_counts.columns = ['VictimSex', 'CaseCount']

vic_race_counts = df_unsolved['VictimRace'].value_counts().reset_index()
vic_race_counts.columns = ['VictimRace', 'CaseCount']

sns.barplot(data=sex_counts, x='CaseCount', y='OffenderSex', orient='h')
plt.title('Unsolved Cases by Offender Sex')
plt.xlabel('Number of Cases')
plt.ylabel('Offender Sex')
plt.show()

sns.barplot(race_counts,x='CaseCount', y='OffenderRace', orient='h')
plt.title('Unsolved Cases by Offender Race')
plt.xlabel('Number of Cases')
plt.ylabel('Offender Race')
plt.show()

sns.barplot(data=vic_sex_counts, x='CaseCount', y='VictimSex', orient='h')
plt.title('Unsolved Cases by Victim Sex')
plt.xlabel('Number of Cases')
plt.ylabel('Victim Sex')
plt.show()

sns.barplot(vic_race_counts,x='CaseCount', y='VictimRace', orient='h')
plt.title('Unsolved Cases by Victim Race')
plt.xlabel('Number of Cases')
plt.ylabel('Victim Race')
plt.show()

# %%
print(df_unsolved['CrimeSituation'].value_counts(), '\n')
print(df_unsolved['WeaponUsed'].value_counts(), '\n')
print(df_unsolved['VictimOffenderRelationship'].value_counts())
# Out:
# CrimeSituation
# Single victim/single offender           1388
# Single victim/unknown offender(s)        386
# Single victim/multiple offenders         328
# Multiple victims/single offender         146
# Multiple victims/multiple offenders       60
# Multiple victims/unknown offender(s)      41
# Name: count, dtype: int64
#
# WeaponUsed
# Firearm, type not stated                880
# Handgun - pistol, revolver, etc         816
# Other or type unknown                   216
# Knife or cutting instrument             139
# Other gun                                83
# Rifle                                    65
# Personal weapons, includes beating       54
# Blunt object - hammer, club, etc         38
# Shotgun                                  23
# Narcotics or drugs, sleeping pills       21
# Fire                                      9
# Weapon Not Reported                       2
# Poison - does not include gas             1
# Asphyxiation - includes death by gas      1
# Explosives                                1
# Name: count, dtype: int64
#
# VictimOffenderRelationship
# Relationship not determined    1966
# Stranger                        202
# Acquaintance                     83
# Other - known to victim          35
# Other family                     13
# Friend                            9
# Girlfriend                        7
# Boyfriend                         5
# Son                               5
# Mother                            3
# Daughter                          3
# Husband                           3
# Neighbor                          3
# Wife                              3
# Brother                           3
# Father                            1
# Employee                          1
# Homosexual relationship           1
# Common-law wife                   1
# Ex-husband                        1
# In-law                            1
# Name: count, dtype: int64

# %% [markdown]
# # <b>Predicting demographic features of unsolved cases based off solved cases

# %% [markdown]
# ## Virginia - predicting Offender Age, Race, Gender, and VictimOffenderRelationship

# %%
df[df['State'] == 'Virginia']
# Out:
#             CountyFIPS     State                        AgencyName  \
# 845310    Accomack, VA  Virginia                   Accomack County
# 845311    Accomack, VA  Virginia                   Accomack County
# 845312    Accomack, VA  Virginia                   Accomack County
# 845313    Accomack, VA  Virginia                   Accomack County
# 845314    Accomack, VA  Virginia                   Accomack County
# ...                ...       ...                               ...
# 867759  Alexandria, VA  Virginia  Pentagon Force Protection Agency
# 867760   Arlington, VA  Virginia           Reagan National Airport
# 867761   Arlington, VA  Virginia           Reagan National Airport
# 867762   Arlington, VA  Virginia           Reagan National Airport
# 867763   Arlington, VA  Virginia           Reagan National Airport
#
#                 AgencyType SolvedStatus  YearReported MonthReported  \
# 845310             Sheriff          Yes          1976     September
# 845311             Sheriff          Yes          1976      November
# 845312             Sheriff          Yes          1976      November
# 845313             Sheriff          Yes          1976      December
# 845314             Sheriff          Yes          1976      December
# ...                    ...          ...           ...           ...
# 867759  Primary federal LE          Yes          2021        August
# 867760      Special police          Yes          1997         March
# 867761      Special police          Yes          2000         March
# 867762      Special police          Yes          2002      November
# 867763      Special police          Yes          2006        August
#
#         IncidentID ReportActionType                           HomicideType  \
# 845310           1    Normal update  Murder and non-negligent manslaughter
# 845311           1    Normal update  Murder and non-negligent manslaughter
# 845312           2    Normal update  Murder and non-negligent manslaughter
# 845313           1    Normal update  Murder and non-negligent manslaughter
# 845314           2    Normal update  Murder and non-negligent manslaughter
# ...            ...              ...                                    ...
# 867759           1    Normal update  Murder and non-negligent manslaughter
# 867760           1    Normal update  Murder and non-negligent manslaughter
# 867761           1    Normal update  Murder and non-negligent manslaughter
# 867762           1    Normal update  Murder and non-negligent manslaughter
# 867763           1    Normal update  Murder and non-negligent manslaughter
#
#         ...          VictimEthnicity  OffenderAge OffenderSex OffenderRace  \
# 845310  ...  Unknown or not reported           62        Male        Black
# 845311  ...  Unknown or not reported           22        Male        Asian
# 845312  ...  Unknown or not reported           47        Male        Asian
# 845313  ...  Unknown or not reported           46        Male        Black
# 845314  ...  Unknown or not reported           21        Male        Black
# ...     ...                      ...          ...         ...          ...
# 867759  ...          Hispanic origin           27        Male      Unknown
# 867760  ...  Unknown or not reported           26      Female        Black
# 867761  ...  Unknown or not reported           46        Male        White
# 867762  ...  Unknown or not reported           22        Male        Black
# 867763  ...  Unknown or not reported           32        Male        Black
#
#                               WeaponUsed   VictimOffenderRelationship  \
# 845310   Handgun - pistol, revolver, etc                     Stranger
# 845311  Blunt object - hammer, club, etc                 Acquaintance
# 845312          Firearm, type not stated                 Acquaintance
# 845313                          Drowning                 Acquaintance
# 845314                           Shotgun                 Acquaintance
# ...                                  ...                          ...
# 867759          Firearm, type not stated  Relationship not determined
# 867760             Other or type unknown      Other - known to victim
# 867761  Blunt object - hammer, club, etc                 Acquaintance
# 867762             Other or type unknown                 Acquaintance
# 867763             Other or type unknown      Other - known to victim
#
#        CrimeCircumstance AdditionalVictimCount AdditionalOffenderCount  \
# 845310          Gambling                     0                       0
# 845311   Other arguments                     0                       0
# 845312   Other arguments                     0                       0
# 845313   Other arguments                     0                       0
# 845314   Other arguments                     0                       0
# ...                  ...                   ...                     ...
# 867759             Other                     0                       0
# 867760             Other                     0                       0
# 867761   Other arguments                     0                       0
# 867762   Other arguments                     0                       0
# 867763   Other arguments                     0                       0
#
#                                     MetropolitanArea
# 845310                                Rural Virginia
# 845311                                Rural Virginia
# 845312                                Rural Virginia
# 845313                                Rural Virginia
# 845314                                Rural Virginia
# ...                                              ...
# 867759  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 867760  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 867761  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 867762  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 867763  Washington-Arlington-Alexandria, DC-VA-MD-WV
#
# [17215 rows x 24 columns]

# %%
df_virginia_solved = df[(df['State'] == 'Virginia') & (df['SolvedStatus'] == 'Yes')]
df_virginia_solved
# Out:
#             CountyFIPS     State                        AgencyName  \
# 845310    Accomack, VA  Virginia                   Accomack County
# 845311    Accomack, VA  Virginia                   Accomack County
# 845312    Accomack, VA  Virginia                   Accomack County
# 845313    Accomack, VA  Virginia                   Accomack County
# 845314    Accomack, VA  Virginia                   Accomack County
# ...                ...       ...                               ...
# 867759  Alexandria, VA  Virginia  Pentagon Force Protection Agency
# 867760   Arlington, VA  Virginia           Reagan National Airport
# 867761   Arlington, VA  Virginia           Reagan National Airport
# 867762   Arlington, VA  Virginia           Reagan National Airport
# 867763   Arlington, VA  Virginia           Reagan National Airport
#
#                 AgencyType SolvedStatus  YearReported MonthReported  \
# 845310             Sheriff          Yes          1976     September
# 845311             Sheriff          Yes          1976      November
# 845312             Sheriff          Yes          1976      November
# 845313             Sheriff          Yes          1976      December
# 845314             Sheriff          Yes          1976      December
# ...                    ...          ...           ...           ...
# 867759  Primary federal LE          Yes          2021        August
# 867760      Special police          Yes          1997         March
# 867761      Special police          Yes          2000         March
# 867762      Special police          Yes          2002      November
# 867763      Special police          Yes          2006        August
#
#         IncidentID ReportActionType                           HomicideType  \
# 845310           1    Normal update  Murder and non-negligent manslaughter
# 845311           1    Normal update  Murder and non-negligent manslaughter
# 845312           2    Normal update  Murder and non-negligent manslaughter
# 845313           1    Normal update  Murder and non-negligent manslaughter
# 845314           2    Normal update  Murder and non-negligent manslaughter
# ...            ...              ...                                    ...
# 867759           1    Normal update  Murder and non-negligent manslaughter
# 867760           1    Normal update  Murder and non-negligent manslaughter
# 867761           1    Normal update  Murder and non-negligent manslaughter
# 867762           1    Normal update  Murder and non-negligent manslaughter
# 867763           1    Normal update  Murder and non-negligent manslaughter
#
#         ...          VictimEthnicity  OffenderAge OffenderSex OffenderRace  \
# 845310  ...  Unknown or not reported           62        Male        Black
# 845311  ...  Unknown or not reported           22        Male        Asian
# 845312  ...  Unknown or not reported           47        Male        Asian
# 845313  ...  Unknown or not reported           46        Male        Black
# 845314  ...  Unknown or not reported           21        Male        Black
# ...     ...                      ...          ...         ...          ...
# 867759  ...          Hispanic origin           27        Male      Unknown
# 867760  ...  Unknown or not reported           26      Female        Black
# 867761  ...  Unknown or not reported           46        Male        White
# 867762  ...  Unknown or not reported           22        Male        Black
# 867763  ...  Unknown or not reported           32        Male        Black
#
#                               WeaponUsed   VictimOffenderRelationship  \
# 845310   Handgun - pistol, revolver, etc                     Stranger
# 845311  Blunt object - hammer, club, etc                 Acquaintance
# 845312          Firearm, type not stated                 Acquaintance
# 845313                          Drowning                 Acquaintance
# 845314                           Shotgun                 Acquaintance
# ...                                  ...                          ...
# 867759          Firearm, type not stated  Relationship not determined
# 867760             Other or type unknown      Other - known to victim
# 867761  Blunt object - hammer, club, etc                 Acquaintance
# 867762             Other or type unknown                 Acquaintance
# 867763             Other or type unknown      Other - known to victim
#
#        CrimeCircumstance AdditionalVictimCount AdditionalOffenderCount  \
# 845310          Gambling                     0                       0
# 845311   Other arguments                     0                       0
# 845312   Other arguments                     0                       0
# 845313   Other arguments                     0                       0
# 845314   Other arguments                     0                       0
# ...                  ...                   ...                     ...
# 867759             Other                     0                       0
# 867760             Other                     0                       0
# 867761   Other arguments                     0                       0
# 867762   Other arguments                     0                       0
# 867763   Other arguments                     0                       0
#
#                                     MetropolitanArea
# 845310                                Rural Virginia
# 845311                                Rural Virginia
# 845312                                Rural Virginia
# 845313                                Rural Virginia
# 845314                                Rural Virginia
# ...                                              ...
# 867759  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 867760  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 867761  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 867762  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 867763  Washington-Arlington-Alexandria, DC-VA-MD-WV
#
# [17178 rows x 24 columns]

# %% [markdown]
# # Identify and drop the missing values

# %%
df_virginia_solved['VictimSex'] = df_virginia_solved['VictimSex'].replace('Unknown', np.nan)
print(df_virginia_solved['VictimSex'].value_counts(), '\n')

df_virginia_solved['VictimRace'] = df_virginia_solved['VictimRace'].replace('Unknown', np.nan)
print(df_virginia_solved['VictimRace'].value_counts(), '\n')

df_virginia_solved['VictimOffenderRelationship'] = df_virginia_solved['VictimOffenderRelationship'].replace('Relationship not determined', np.nan)
print(df_virginia_solved['VictimOffenderRelationship'].value_counts(), '\n')

df_virginia_solved['WeaponUsed'] = df_virginia_solved['WeaponUsed'].replace('Other or type unknown', np.nan)
print(df_virginia_solved['WeaponUsed'].value_counts(), '\n')

df_virginia_solved['CrimeSituation'] = df_virginia_solved['CrimeSituation'].replace('Unknown', np.nan)
print(df_virginia_solved['CrimeSituation'].value_counts(), '\n')

df_virginia_solved['CrimeCircumstance'] = df_virginia_solved['CrimeCircumstance'].replace('Circumstances undetermined', np.nan)
print(df_virginia_solved['CrimeCircumstance'].value_counts(), '\n')

print(df_virginia_solved['OffenderSex'].value_counts(), '\n')

df_virginia_solved['OffenderRace'] = df_virginia_solved['OffenderRace'].replace('Unknown', np.nan)
print(df_virginia_solved['OffenderRace'].value_counts(), '\n')

print(df_virginia_solved['OffenderAge'].value_counts(), '\n')

print(df_virginia_solved['HomicideType'].value_counts())
df_virginia_solved.dropna(inplace=True)
df_virginia_solved.isnull().sum()
# Out:
# VictimSex
# Male      12463
# Female     4708
# Name: count, dtype: int64
#
# VictimRace
# Black                                  9414
# White                                  7471
# Asian                                   169
# American Indian or Alaskan Native        19
# Native Hawaiian or Pacific Islander       1
# Name: count, dtype: int64
#
# VictimOffenderRelationship
# Acquaintance               5460
# Stranger                   2254
# Wife                       1096
# Girlfriend                  772
# Other - known to victim     744
# Friend                      577
# Husband                     453
# Other family                380
# Son                         368
# Boyfriend                   343
# Daughter                    274
# Brother                     243
# Father                      242
# Neighbor                    235
# Mother                      189
# In-law                      183
# Sister                       81
# Ex-wife                      64
# Stepfather                   58
# Stepson                      43
# Homosexual relationship      39
# Common-law wife              34
# Stepdaughter                 28
# Common-law husband           17
# Employer                     17
# Stepmother                   14
# Employee                     13
# Ex-husband                   12
# Name: count, dtype: int64
#
# WeaponUsed
# Handgun - pistol, revolver, etc         7620
# Knife or cutting instrument             2322
# Firearm, type not stated                2175
# Shotgun                                 1122
# Personal weapons, includes beating       935
# Rifle                                    704
# Blunt object - hammer, club, etc         522
# Fire                                     150
# Narcotics or drugs, sleeping pills       122
# Asphyxiation - includes death by gas     114
# Strangulation - hanging                   93
# Other gun                                 53
# Drowning                                  27
# Poison - does not include gas              7
# Pushed or thrown out window                3
# Explosives                                 1
# Name: count, dtype: int64
#
# CrimeSituation
# Single victim/single offender          12721
# Single victim/multiple offenders        2692
# Multiple victims/single offender        1384
# Multiple victims/multiple offenders      381
# Name: count, dtype: int64
#
# CrimeCircumstance
# Other arguments                         6395
# Other                                   2912
# Robbery                                  914
# Narcotic drug laws                       606
# All other manslaughter by negligence     394
# Felon killed by police                   317
# Lovers triangle                          274
# Felon killed by private citizen          261
# Brawl due to influence of alcohol        197
# Argument over money or property          146
# Other - not specified                    129
# Burglary                                 116
# Arson                                     86
# Rape                                      83
# Other negligent handling of gun           78
# Motor vehicle theft                       55
# Gangland killings                         53
# Brawl due to influence of narcotics       52
# Larceny                                   50
# Other sex offense                         48
# Children playing with gun                 35
# Victim shot in hunting accident           26
# Child killed by babysitter                25
# Gambling                                  18
# All suspected felony type                 17
# Institutional killings                    15
# Juvenile gang killings                    13
# Prostitution and commercialized vice      11
# Gun-cleaning death - other than self       4
# Sniper attack                              3
# Name: count, dtype: int64
#
# OffenderSex
# Male      15063
# Female     2115
# Name: count, dtype: int64
#
# OffenderRace
# Black                                10159
# White                                 6776
# Asian                                  177
# American Indian or Alaskan Native       14
# Name: count, dtype: int64
#
# OffenderAge
# 20    830
# 19    808
# 21    780
# 23    773
# 22    743
#      ...
# 98      1
# 89      1
# 96      1
# 94      1
# 4       1
# Name: count, Length: 93, dtype: int64
#
# HomicideType
# Murder and non-negligent manslaughter    16641
# Manslaughter by negligence                 537
# Name: count, dtype: int64
# <ipython-input-49-df23f69a10a4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_virginia_solved['VictimSex'] = df_virginia_solved['VictimSex'].replace('Unknown', np.nan)
# <ipython-input-49-df23f69a10a4>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_virginia_solved['VictimRace'] = df_virginia_solved['VictimRace'].replace('Unknown', np.nan)
# <ipython-input-49-df23f69a10a4>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_virginia_solved['VictimOffenderRelationship'] = df_virginia_solved['VictimOffenderRelationship'].replace('Relationship not determined', np.nan)
# <ipython-input-49-df23f69a10a4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_virginia_solved['WeaponUsed'] = df_virginia_solved['WeaponUsed'].replace('Other or type unknown', np.nan)
# <ipython-input-49-df23f69a10a4>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_virginia_solved['CrimeSituation'] = df_virginia_solved['CrimeSituation'].replace('Unknown', np.nan)
# <ipython-input-49-df23f69a10a4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_virginia_solved['CrimeCircumstance'] = df_virginia_solved['CrimeCircumstance'].replace('Circumstances undetermined', np.nan)
# <ipython-input-49-df23f69a10a4>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_virginia_solved['OffenderRace'] = df_virginia_solved['OffenderRace'].replace('Unknown', np.nan)
# <ipython-input-49-df23f69a10a4>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_virginia_solved.dropna(inplace=True)
# CountyFIPS                    0
# State                         0
# AgencyName                    0
# AgencyType                    0
# SolvedStatus                  0
# YearReported                  0
# MonthReported                 0
# IncidentID                    0
# ReportActionType              0
# HomicideType                  0
# CrimeSituation                0
# VictimAge                     0
# VictimSex                     0
# VictimRace                    0
# VictimEthnicity               0
# OffenderAge                   0
# OffenderSex                   0
# OffenderRace                  0
# WeaponUsed                    0
# VictimOffenderRelationship    0
# CrimeCircumstance             0
# AdditionalVictimCount         0
# AdditionalOffenderCount       0
# MetropolitanArea              0
# dtype: int64

# %% [markdown]
# # Train a Random Forest Classifier model to predict offender <b>sex</b> from the solved cases dataset in the state of virginia

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score


# identify needed features and target variables
features = ['VictimAge', 'VictimSex', 'VictimRace', 'WeaponUsed',
            'VictimOffenderRelationship', 'CrimeCircumstance',
            'CrimeSituation', 'HomicideType']
target = 'OffenderSex'

y = df_virginia_solved[target]

# identify categorical features for one-hot encoding
categorical_features = ['VictimSex', 'VictimRace', 'WeaponUsed',
                        'VictimOffenderRelationship',
                         'HomicideType','CrimeCircumstance','CrimeSituation']

# one-hot encode the categorical variables
X_dummies = df_virginia_solved[categorical_features]
X_encoded = pd.get_dummies(X_dummies, drop_first=True)

# merge the dataset to include the numeric variable of Victim Age
X_numeric = df_virginia_solved[['VictimAge']]
X_final = pd.concat([X_numeric, X_encoded], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, stratify=y, random_state=42)

# train via randomforest classifier
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# evaluate outcome
y_pred = model.predict(X_test)
accuracy = (accuracy_score(y_test, y_pred))*100
print(f'classification report: {classification_report(y_test, y_pred)}\n')
print(f'confusion matrix: {confusion_matrix(y_test, y_pred)}\n')
print(f'Accuracy score of the random forest classifier is {accuracy:.2f}%')
# Out:
# classification report:               precision    recall  f1-score   support
#
#       Female       0.70      0.59      0.64       302
#         Male       0.94      0.96      0.95      1979
#
#     accuracy                           0.91      2281
#    macro avg       0.82      0.77      0.79      2281
# weighted avg       0.91      0.91      0.91      2281
#
#
# confusion matrix: [[ 177  125]
#  [  76 1903]]
#
# Accuracy score of the random forest classifier is 91.19%

# %% [markdown]
# # Predict and impute offender sex from the unsolved Virginia Dataset

# %%
# find the unsolved cases dataset for predictive imputation
df_virginia_unsolved = df[(df['State'] == 'Virginia') & (df['SolvedStatus'] == 'No')].copy()

# df_virginia_unsolved['VictimSex'] = df_virginia_unsolved['VictimSex'].replace('Unknown', np.nan)
# df_virginia_unsolved['VictimRace'] = df_virginia_unsolved['VictimRace'].replace('Unknown', np.nan)
# df_virginia_unsolved['VictimOffenderRelationship'] = df_virginia_unsolved['VictimOffenderRelationship'].replace('Relationship not determined', np.nan)
# df_virginia_unsolved['WeaponUsed'] = df_virginia_unsolved['WeaponUsed'].replace('Other or type unknown', np.nan)
# df_virginia_unsolved['CrimeSituation'] = df_virginia_unsolved['CrimeSituation'].replace('Unknown', np.nan)
# df_virginia_unsolved['CrimeCircumstance'] = df_virginia_unsolved['CrimeCircumstance'].replace('Circumstances undetermined', np.nan)
# df_virginia_unsolved['OffenderRace'] = df_virginia_unsolved['OffenderRace'].replace('Unknown', np.nan)

# one-hot encode categorical variables and combine them together with the continuous variable 'age'
X_unsolved_dummies = df_virginia_unsolved[categorical_features]
X_unsolved_encoded = pd.get_dummies(X_unsolved_dummies, drop_first=True)
X_unsolved_numeric = df_virginia_unsolved[['VictimAge']]

X_unsolved_final = pd.concat([X_unsolved_numeric, X_unsolved_encoded], axis=1)

# align features of the encoded dataset with the training set above so that prediction can be accurately carried out
def align_features(X_train, X_new):
    missing_cols = set(X_train.columns) - set(X_new.columns)
    for col in missing_cols:
        X_new[col] = 0
    extra_cols = set(X_new.columns) - set(X_train.columns)
    X_new = X_new.drop(columns=extra_cols)
    X_new = X_new[X_train.columns]
    return X_new
X_unsolved_final = align_features(X_final, X_unsolved_final)

# predict and fill in the predicted values
unsolved_predictions = model.predict(X_unsolved_final)
df_virginia_unsolved['Predicted_OffenderSex'] = unsolved_predictions
unsolved_probabilities = model.predict_proba(X_unsolved_final)
df_virginia_unsolved['Prob_Male'] = np.round(unsolved_probabilities[:, 1], 2)*100
df_virginia_unsolved['Prob_Female'] = np.round(unsolved_probabilities[:, 0], 2)*100
print(model.classes_)
df_virginia_unsolved.head(7)
# Out:
# ['Female' 'Male']
#                 CountyFIPS     State                               AgencyName  \
# 845735         Amherst, VA  Virginia                           Amherst County
# 848941      Gloucester, VA  Virginia                        Gloucester County
# 849388         Hanover, VA  Virginia                           Hanover County
# 849908         Henrico, VA  Virginia                  Henrico County Police D
# 850937         Loudoun, VA  Virginia                                 Leesburg
# 851248     Mecklenburg, VA  Virginia                       Mecklenburg County
# 852505  Prince William, VA  Virginia  Prince William County Police Department
#
#               AgencyType SolvedStatus  YearReported MonthReported  IncidentID  \
# 845735           Sheriff           No          2017      December           1
# 848941           Sheriff           No          2022       October           1
# 849388           Sheriff           No          2004        August           1
# 849908     County police           No          2011         April           1
# 850937  Municipal police           No          2009         March           1
# 851248           Sheriff           No          2022         March           1
# 852505     County police           No          2001     September           1
#
#        ReportActionType                           HomicideType  ...  \
# 845735    Normal update             Manslaughter by negligence  ...
# 848941    Normal update  Murder and non-negligent manslaughter  ...
# 849388    Normal update  Murder and non-negligent manslaughter  ...
# 849908    Normal update  Murder and non-negligent manslaughter  ...
# 850937    Normal update  Murder and non-negligent manslaughter  ...
# 851248    Normal update  Murder and non-negligent manslaughter  ...
# 852505    Normal update  Murder and non-negligent manslaughter  ...
#
#        OffenderRace                          WeaponUsed  \
# 845735      Unknown  Narcotics or drugs, sleeping pills
# 848941      Unknown         Knife or cutting instrument
# 849388      Unknown               Other or type unknown
# 849908      Unknown     Handgun - pistol, revolver, etc
# 850937      Unknown         Knife or cutting instrument
# 851248      Unknown            Firearm, type not stated
# 852505      Unknown         Knife or cutting instrument
#
#          VictimOffenderRelationship                     CrimeCircumstance  \
# 845735  Relationship not determined  All other manslaughter by negligence
# 848941  Relationship not determined            Circumstances undetermined
# 849388  Relationship not determined            Circumstances undetermined
# 849908      Other - known to victim            Circumstances undetermined
# 850937  Relationship not determined                                 Other
# 851248  Relationship not determined            Circumstances undetermined
# 852505  Relationship not determined            Circumstances undetermined
#
#        AdditionalVictimCount  AdditionalOffenderCount  \
# 845735                     0                        0
# 848941                     0                        0
# 849388                     0                        0
# 849908                     0                        0
# 850937                     0                        0
# 851248                     0                        1
# 852505                     0                        0
#
#                                     MetropolitanArea Predicted_OffenderSex  \
# 845735                                 Lynchburg, VA                Female
# 848941    Virginia Beach-Norfolk-Newport News, VA-NC                  Male
# 849388                                  Richmond, VA                  Male
# 849908                                  Richmond, VA                  Male
# 850937  Washington-Arlington-Alexandria, DC-VA-MD-WV                  Male
# 851248                                Rural Virginia                  Male
# 852505  Washington-Arlington-Alexandria, DC-VA-MD-WV                  Male
#
#        Prob_Male Prob_Female
# 845735      45.0        55.0
# 848941      97.0         3.0
# 849388      97.0         3.0
# 849908      96.0         4.0
# 850937      99.0         1.0
# 851248      97.0         3.0
# 852505      97.0         3.0
#
# [7 rows x 27 columns]

# %% [markdown]
# ## The model is heavily skewed against male offenders, perhaps it is reflective of how the male population could easily become offenders,  more often than women

# %%
df_virginia_unsolved['Predicted_OffenderSex'].value_counts()
# Out:
# Predicted_OffenderSex
# Male      36
# Female     1
# Name: count, dtype: int64

# %% [markdown]
# # Train a Random Forest Classifier model to predict offender <b>race</b> from the solved cases dataset in the state of virginia

# %%
features = ['VictimAge', 'VictimSex', 'VictimRace', 'WeaponUsed',
            'VictimOffenderRelationship', 'CrimeCircumstance',
            'CrimeSituation', 'HomicideType']
target = 'OffenderRace'

y = df_virginia_solved[target]

# identify categorical features for one-hot encoding
categorical_features = ['VictimSex', 'VictimRace', 'WeaponUsed',
                        'VictimOffenderRelationship',
                         'HomicideType','CrimeCircumstance','CrimeSituation']

# one-hot encode the categorical variables
X_dummies = df_virginia_solved[categorical_features]
X_encoded = pd.get_dummies(X_dummies, drop_first=True)

# merge the dataset to include the numeric variable of Victim Age
X_numeric = df_virginia_solved[['VictimAge']]
X_final = pd.concat([X_numeric, X_encoded], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, stratify=y, random_state=42)

# train via randomforest classifier
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# evaluate outcome
y_pred = model.predict(X_test)
accuracy = (accuracy_score(y_test, y_pred))*100
print(f'Accuracy score of the random forest classifier is {accuracy:.2f}%')
# Out:
# Accuracy score of the random forest classifier is 87.46%

# %% [markdown]
# # Predicting and imputing offender race

# %%
# one-hot encode categorical variables and combine them together with the continuous variable 'age'
X_unsolved_dummies = df_virginia_unsolved[categorical_features]
X_unsolved_encoded = pd.get_dummies(X_unsolved_dummies, drop_first=True)
X_unsolved_numeric = df_virginia_unsolved[['VictimAge']]

X_unsolved_final = pd.concat([X_unsolved_numeric, X_unsolved_encoded], axis=1)

# align features of the encoded dataset with the training set above so that prediction can be accurately carried out
def align_features(X_train, X_new):
    missing_cols = set(X_train.columns) - set(X_new.columns)
    for col in missing_cols:
        X_new[col] = 0
    extra_cols = set(X_new.columns) - set(X_train.columns)
    X_new = X_new.drop(columns=extra_cols)
    X_new = X_new[X_train.columns]
    return X_new
X_unsolved_final = align_features(X_final, X_unsolved_final)

# predict and fill in the predicted values
unsolved_predictions = model.predict(X_unsolved_final)
df_virginia_unsolved['Predicted_OffenderRace'] = unsolved_predictions
unsolved_probabilities = model.predict_proba(X_unsolved_final)
df_virginia_unsolved['Prob_Black'] = np.round(unsolved_probabilities[:, 2], 2)*100
df_virginia_unsolved['Prob_White'] = np.round(unsolved_probabilities[:, 3], 2)*100
df_virginia_unsolved['Prob_Asian'] = np.round(unsolved_probabilities[:, 1], 2)*100
df_virginia_unsolved['Prob_American Indian or Alaskan Native'] = np.round(unsolved_probabilities[:, 0], 2)*100
print(model.classes_)
df_virginia_unsolved.head(7)
# Out:
# ['American Indian or Alaskan Native' 'Asian' 'Black' 'White']
#                 CountyFIPS     State                               AgencyName  \
# 845735         Amherst, VA  Virginia                           Amherst County
# 848941      Gloucester, VA  Virginia                        Gloucester County
# 849388         Hanover, VA  Virginia                           Hanover County
# 849908         Henrico, VA  Virginia                  Henrico County Police D
# 850937         Loudoun, VA  Virginia                                 Leesburg
# 851248     Mecklenburg, VA  Virginia                       Mecklenburg County
# 852505  Prince William, VA  Virginia  Prince William County Police Department
#
#               AgencyType SolvedStatus  YearReported MonthReported  IncidentID  \
# 845735           Sheriff           No          2017      December           1
# 848941           Sheriff           No          2022       October           1
# 849388           Sheriff           No          2004        August           1
# 849908     County police           No          2011         April           1
# 850937  Municipal police           No          2009         March           1
# 851248           Sheriff           No          2022         March           1
# 852505     County police           No          2001     September           1
#
#        ReportActionType                           HomicideType  ...  \
# 845735    Normal update             Manslaughter by negligence  ...
# 848941    Normal update  Murder and non-negligent manslaughter  ...
# 849388    Normal update  Murder and non-negligent manslaughter  ...
# 849908    Normal update  Murder and non-negligent manslaughter  ...
# 850937    Normal update  Murder and non-negligent manslaughter  ...
# 851248    Normal update  Murder and non-negligent manslaughter  ...
# 852505    Normal update  Murder and non-negligent manslaughter  ...
#
#        AdditionalOffenderCount                              MetropolitanArea  \
# 845735                       0                                 Lynchburg, VA
# 848941                       0    Virginia Beach-Norfolk-Newport News, VA-NC
# 849388                       0                                  Richmond, VA
# 849908                       0                                  Richmond, VA
# 850937                       0  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 851248                       1                                Rural Virginia
# 852505                       0  Washington-Arlington-Alexandria, DC-VA-MD-WV
#
#        Predicted_OffenderSex Prob_Male Prob_Female  Predicted_OffenderRace  \
# 845735                Female      45.0        55.0                   White
# 848941                  Male      97.0         3.0                   White
# 849388                  Male      97.0         3.0                   White
# 849908                  Male      96.0         4.0                   White
# 850937                  Male      99.0         1.0                   Black
# 851248                  Male      97.0         3.0                   White
# 852505                  Male      97.0         3.0                   White
#
#        Prob_Black Prob_White Prob_Asian Prob_American Indian or Alaskan Native
# 845735       33.0       67.0        0.0                                    0.0
# 848941       37.0       53.0       10.0                                    0.0
# 849388       13.0       87.0        0.0                                    0.0
# 849908       29.0       68.0        3.0                                    0.0
# 850937       55.0       40.0        5.0                                    0.0
# 851248       32.0       45.0       22.0                                    1.0
# 852505       28.0       72.0        0.0                                    0.0
#
# [7 rows x 32 columns]

# %% [markdown]
# ## The model seems to be heavily skewed against white offenders

# %%
df_virginia_unsolved['Predicted_OffenderRace'].value_counts()
# Out:
# Predicted_OffenderRace
# White    33
# Black     4
# Name: count, dtype: int64

# %% [markdown]
# # Train a Random Forest Regressor Model to predict the exact <b>Age</b> of the offender

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, root_mean_squared_error
from sklearn.model_selection import GridSearchCV

# identify needed features and target variables
features = ['VictimAge', 'VictimSex', 'VictimRace', 'WeaponUsed',
            'VictimOffenderRelationship', 'CrimeCircumstance',
            'CrimeSituation', 'HomicideType']
target = 'OffenderAge'

y = df_virginia_solved[target]

# identify categorical features for one-hot encoding
categorical_features = ['VictimSex', 'VictimRace', 'WeaponUsed',
                        'VictimOffenderRelationship',
                         'HomicideType','CrimeCircumstance','CrimeSituation']

# one-hot encode the categorical variables
X_dummies = df_virginia_solved[categorical_features]
X_encoded = pd.get_dummies(X_dummies, drop_first=True)

# merge the dataset to include the numeric variable of Victim Age
X_numeric = df_virginia_solved[['VictimAge']]
X_final = pd.concat([X_numeric, X_encoded], axis=1)

# fine-tuning the regressor to find the best accuracy
parameters = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2']
}

grid_search = GridSearchCV(estimator = RandomForestRegressor(random_state=42),
                           param_grid = parameters,cv=5,
                           n_jobs = -1,
                           verbose = 2,
                           scoring='r2'
                           )

X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, random_state=42)

# train via gridsearch's random forest regressor
grid_search.fit(X_train, y_train)
print('Best Parameters found:', grid_search.best_params_)
print(f'best r^2 score found:{grid_search.best_score_:.2f}%')
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# Best Parameters found: {'max_depth': 30, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 300}
# best r^2 score found:0.42%

# %%
# best parameters according to gridsearch outcome:
# {
#     'max_depth': 30,
#     'max_features': 'sqrt',
#     'min_samples_leaf': 1,
#     'min_samples_split': 10,
#     'n_estimators': 300
# }

# %% [markdown]
# ## Turns out that predicting the exact <b>age</b> is extremely difficult as age could have a weak correlation between all of the crime factors given that human behavior is highly random, and that age does not contrain their criminal acts

# %%
final_model_chosen = RandomForestRegressor(**grid_search.best_params_, random_state=42)
final_model_chosen.fit(X_train, y_train)
y_pred = final_model_chosen.predict(X_test)
r_squared = round(r2_score(y_test, y_pred), 2)*100
print(f'R^2 score is {r_squared}%')
# Out:
# R^2 score is 45.0%

# %% [markdown]
# # Instead of predicting <b>age</b> as a continuous variable, predicting <b>age groups</b> could be a better option

# %% [markdown]
# ### Adding additional two new features: AdditionalVictimCount + AdditionalOffenderCount

# %%
bins = [0, 4, 12, 17, 24, 34, 49, 64, 120]  # upper bound is 120 to cover all possible ages
labels = ['0-4', '5-12', '13-17', '18-24', '25-34', '35-49', '50-64', '65+']
df_virginia_solved['OffenderAgeGroup'] = pd.cut(df_virginia_solved['OffenderAge'], bins=bins, labels=labels)

# identify needed features and target variables

features = ['VictimAge', 'VictimSex', 'VictimRace', 'WeaponUsed',
            'VictimOffenderRelationship', 'CrimeCircumstance',
            'CrimeSituation', 'HomicideType', 'AdditionalOffenderCount',
            'AdditionalVictimCount']
target = 'OffenderAgeGroup'

y = df_virginia_solved[target]

# identify categorical features for one-hot encoding
categorical_features = ['VictimSex', 'VictimRace', 'WeaponUsed',
                        'VictimOffenderRelationship',
                         'HomicideType','CrimeCircumstance','CrimeSituation']

# one-hot encode the categorical variables
X_dummies = df_virginia_solved[categorical_features]
X_encoded = pd.get_dummies(X_dummies, drop_first=True)

# merge the dataset to include the numeric variable of Victim Age
X_numeric = df_virginia_solved[['VictimAge', 'AdditionalOffenderCount', 'AdditionalVictimCount']]
X_final = pd.concat([X_numeric, X_encoded], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, stratify=y, random_state=42)

# train via randomforest classifier
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# evaluate outcome
y_pred = model.predict(X_test)
accuracy = (accuracy_score(y_test, y_pred))*100
print(f'\nAccuracy score of the random forest classifier is {accuracy:.2f}%')

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for Offender Age Group Prediction')
plt.show()
# Out:
# <ipython-input-61-6fd97d238017>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_virginia_solved['OffenderAgeGroup'] = pd.cut(df_virginia_solved['OffenderAge'], bins=bins, labels=labels)
# Accuracy score of the random forest classifier is 43.31%

# %% [markdown]
# ## Finding out about the feature importance scores to determine which features are nice

# %%
feature_importances = model.feature_importances_
feature_names = X_final.columns
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Grouping dummy variables back to their original feature
feature_importance_df['BaseFeature'] = feature_importance_df['Feature'].apply(lambda x: x.split('_')[0])

grouped_importance = feature_importance_df.groupby('BaseFeature')['Importance'].sum().reset_index()
grouped_importance = grouped_importance.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='BaseFeature', data=grouped_importance)
plt.xlabel('Total Importance Score')
plt.ylabel('Feature Group')
plt.title('Feature Importance of the used features during training')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dropping certain features with low feature importance: Remaining features with high importance are as follows:
# - Victim Age
# - WeaponUsed
# - CrimeCircumstance
# - VictimOffenderRelationship

# %% [markdown]
# ## Testing whether accuracy increased after low importance features have been dropped

# %%
bins = [0, 4, 12, 17, 24, 34, 49, 64, 120]  # upper bound is 120 to cover all possible ages
labels = ['0-4', '5-12', '13-17', '18-24', '25-34', '35-49', '50-64', '65+']
df_virginia_solved.loc[:, 'OffenderAgeGroup'] = pd.cut(df_virginia_solved['OffenderAge'], bins=bins, labels=labels)

# identify needed features and target variables

features = ['VictimAge', 'WeaponUsed',
            'VictimOffenderRelationship', 'CrimeCircumstance']
target = 'OffenderAgeGroup'

y = df_virginia_solved[target]

# identify categorical features for one-hot encoding
categorical_features = ['WeaponUsed',
                        'VictimOffenderRelationship',
                        'CrimeCircumstance']

# one-hot encode the categorical variables
X_dummies = df_virginia_solved[categorical_features]
X_encoded = pd.get_dummies(X_dummies, drop_first=True)

# merge the dataset to include the numeric variable of Victim Age
X_numeric = df_virginia_solved[['VictimAge']]
X_final = pd.concat([X_numeric, X_encoded], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, stratify=y, random_state=42)

# train via randomforest classifier
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# evaluate outcome
y_pred = model.predict(X_test)
accuracy = (accuracy_score(y_test, y_pred))*100
print(f'\nAccuracy score of the random forest classifier is {accuracy:.2f}%')

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for Offender Age Group Prediction')
plt.show()
# Out:
# Accuracy score of the random forest classifier is 42.26%

# %% [markdown]
# ## Fine tuning features with the best parameter combination previously found through grid-search

# %%
final_model_chosen = RandomForestClassifier(
    max_depth=30,
    max_features='sqrt',
    min_samples_leaf=1,
    min_samples_split=10,
    n_estimators=300,
    random_state=42
)
final_model_chosen.fit(X_train, y_train)
y_pred = final_model_chosen.predict(X_test)
accuracy = accuracy_score(y_test, y_pred) * 100
print(f'Accuracy score of the RandomForestClassifier: {accuracy:.2f}%')
# Out:
# Accuracy score of the RandomForestClassifier: 43.88%

# %% [markdown]
# ## Turns out that predicting age is quite challenging, even by classifying age groups

# %% [markdown]
# ## Attempt to predict and impute age groups to the unsolved dataset

# %%
X_unsolved_dummies = df_virginia_unsolved[categorical_features]
X_unsolved_encoded = pd.get_dummies(X_unsolved_dummies, drop_first=True)
X_unsolved_numeric = df_virginia_unsolved[['VictimAge']]

X_unsolved_final = pd.concat([X_unsolved_numeric, X_unsolved_encoded], axis=1)

# align features of the encoded dataset with the training set above so that prediction can be accurately carried out
def align_features(X_train, X_new):
    missing_cols = set(X_train.columns) - set(X_new.columns)
    for col in missing_cols:
        X_new[col] = 0
    extra_cols = set(X_new.columns) - set(X_train.columns)
    X_new = X_new.drop(columns=extra_cols)
    X_new = X_new[X_train.columns]
    return X_new
X_unsolved_final = align_features(X_final, X_unsolved_final)

# predict and fill in the predicted values
unsolved_predictions = model.predict(X_unsolved_final)
df_virginia_unsolved['Predicted_AgeGroup'] = unsolved_predictions
unsolved_probabilities = model.predict_proba(X_unsolved_final)
df_virginia_unsolved['Prob_13-17'] = np.round(unsolved_probabilities[:, 0], 2)*100
df_virginia_unsolved['Prob_18-24'] = np.round(unsolved_probabilities[:, 1], 2)*100
df_virginia_unsolved['Prob_25-34'] = np.round(unsolved_probabilities[:, 2], 2)*100
df_virginia_unsolved['Prob_35-49'] = np.round(unsolved_probabilities[:, 3], 2)*100
df_virginia_unsolved['Prob_5-12'] = np.round(unsolved_probabilities[:, 4], 2)*100
df_virginia_unsolved['Prob_50-64'] = np.round(unsolved_probabilities[:, 5], 2)*100
df_virginia_unsolved['Prob_65+'] = np.round(unsolved_probabilities[:, 6], 2)*100
print(model.classes_)
df_virginia_unsolved.iloc[:, 24:].head()
# Out:
# ['13-17' '18-24' '25-34' '35-49' '5-12' '50-64' '65+']
#        Predicted_OffenderSex  Prob_Male  Prob_Female Predicted_OffenderRace  \
# 845735                Female       45.0         55.0                  White
# 848941                  Male       97.0          3.0                  White
# 849388                  Male       97.0          3.0                  White
# 849908                  Male       96.0          4.0                  White
# 850937                  Male       99.0          1.0                  Black
#
#         Prob_Black  Prob_White  Prob_Asian  \
# 845735        33.0        67.0         0.0
# 848941        37.0        53.0        10.0
# 849388        13.0        87.0         0.0
# 849908        29.0        68.0         3.0
# 850937        55.0        40.0         5.0
#
#         Prob_American Indian or Alaskan Native Predicted_AgeGroup  Prob_13-17  \
# 845735                                     0.0              18-24         0.0
# 848941                                     0.0              18-24         3.0
# 849388                                     0.0              25-34         1.0
# 849908                                     0.0              25-34         2.0
# 850937                                     0.0              18-24         0.0
#
#         Prob_18-24  Prob_25-34  Prob_35-49  Prob_5-12  Prob_50-64  Prob_65+
# 845735        72.0        23.0         2.0        0.0         3.0       0.0
# 848941        82.0        10.0         4.0        0.0         1.0       0.0
# 849388        28.0        54.0        10.0        0.0         7.0       1.0
# 849908        23.0        71.0         4.0        0.0         0.0       0.0
# 850937        49.0        44.0         5.0        0.0         0.0       2.0

# %%
df_virginia_unsolved['VictimOffenderRelationship'].value_counts()
# Out:
# VictimOffenderRelationship
# Relationship not determined    32
# Other - known to victim         2
# Stranger                        2
# Other family                    1
# Name: count, dtype: int64

# %% [markdown]
# ## Training another random forest classifier model to predict <b>victim offender relationship</b>

# %%
features = ['VictimAge', 'VictimSex', 'VictimRace', 'WeaponUsed',
            'CrimeCircumstance', 'CrimeSituation', 'HomicideType']
target = 'VictimOffenderRelationship'

y = df_virginia_solved[target]

# identify categorical features for one-hot encoding
categorical_features = ['VictimSex', 'VictimRace', 'WeaponUsed',
                         'HomicideType','CrimeCircumstance','CrimeSituation']

# one-hot encode the categorical variables
X_dummies = df_virginia_solved[categorical_features]
X_encoded = pd.get_dummies(X_dummies, drop_first=True)

# merge the dataset to include the numeric variable of Victim Age
X_numeric = df_virginia_solved[['VictimAge']]
X_final = pd.concat([X_numeric, X_encoded], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, stratify=y, random_state=42)

# train via randomforest classifier
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# evaluate outcome
y_pred = model.predict(X_test)
accuracy = (accuracy_score(y_test, y_pred))*100
relationship_labels = sorted(y_test.unique())
print(f'Accuracy score of the random forest classifier is {accuracy:.2f}%')
# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues', xticklabels=relationship_labels, yticklabels=relationship_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for Victim Offender Relationship Prediction')
plt.show()
# Out:
# Accuracy score of the random forest classifier is 43.27%

# %% [markdown]
# ## Attempt to predict and impute data for the unsolved cases

# %%
X_unsolved_dummies = df_virginia_unsolved[categorical_features]
X_unsolved_encoded = pd.get_dummies(X_unsolved_dummies, drop_first=True)
X_unsolved_numeric = df_virginia_unsolved[['VictimAge']]

X_unsolved_final = pd.concat([X_unsolved_numeric, X_unsolved_encoded], axis=1)

# align features of the encoded dataset with the training set above so that prediction can be accurately carried out
def align_features(X_train, X_new):
    missing_cols = set(X_train.columns) - set(X_new.columns)
    for col in missing_cols:
        X_new[col] = 0
    extra_cols = set(X_new.columns) - set(X_train.columns)
    X_new = X_new.drop(columns=extra_cols)
    X_new = X_new[X_train.columns]
    return X_new
X_unsolved_final = align_features(X_final, X_unsolved_final)

# predict and fill in the predicted values
unsolved_predictions = model.predict(X_unsolved_final)
df_virginia_unsolved['Predicted_VictimOffenderRelationship'] = unsolved_predictions
unsolved_probabilities = model.predict_proba(X_unsolved_final)
for idx, relationship_class in enumerate(model.classes_):
    df_virginia_unsolved[f'Prob_{relationship_class}'] = np.round(unsolved_probabilities[:, idx], 2)*100
print(model.classes_)
df_virginia_unsolved.iloc[:, 24:].head()
# Out:
# ['Acquaintance' 'Boyfriend' 'Brother' 'Common-law husband'
#  'Common-law wife' 'Daughter' 'Employee' 'Employer' 'Ex-husband' 'Ex-wife'
#  'Father' 'Friend' 'Girlfriend' 'Homosexual relationship' 'Husband'
#  'In-law' 'Mother' 'Neighbor' 'Other - known to victim' 'Other family'
#  'Sister' 'Son' 'Stepdaughter' 'Stepfather' 'Stepmother' 'Stepson'
#  'Stranger' 'Wife']
#        Predicted_OffenderSex  Prob_Male  Prob_Female Predicted_OffenderRace  \
# 845735                Female       45.0         55.0                  White
# 848941                  Male       97.0          3.0                  White
# 849388                  Male       97.0          3.0                  White
# 849908                  Male       96.0          4.0                  White
# 850937                  Male       99.0          1.0                  Black
#
#         Prob_Black  Prob_White  Prob_Asian  \
# 845735        33.0        67.0         0.0
# 848941        37.0        53.0        10.0
# 849388        13.0        87.0         0.0
# 849908        29.0        68.0         3.0
# 850937        55.0        40.0         5.0
#
#         Prob_American Indian or Alaskan Native Predicted_AgeGroup  Prob_13-17  \
# 845735                                     0.0              18-24         0.0
# 848941                                     0.0              18-24         3.0
# 849388                                     0.0              25-34         1.0
# 849908                                     0.0              25-34         2.0
# 850937                                     0.0              18-24         0.0
#
#         ...  Prob_Other - known to victim  Prob_Other family  Prob_Sister  \
# 845735  ...                          39.0                1.0          0.0
# 848941  ...                           5.0                0.0          0.0
# 849388  ...                           2.0                1.0          0.0
# 849908  ...                           0.0                0.0          0.0
# 850937  ...                           0.0                0.0          0.0
#
#         Prob_Son  Prob_Stepdaughter  Prob_Stepfather Prob_Stepmother  \
# 845735       0.0                0.0              0.0             0.0
# 848941       0.0                0.0              1.0             0.0
# 849388       1.0                0.0              0.0             0.0
# 849908       0.0                0.0              2.0             0.0
# 850937       0.0                0.0              0.0             0.0
#
#         Prob_Stepson  Prob_Stranger  Prob_Wife
# 845735           0.0            1.0        0.0
# 848941           0.0           17.0        0.0
# 849388           1.0           18.0        0.0
# 849908           0.0           27.0        0.0
# 850937           0.0           15.0        5.0
#
# [5 rows x 45 columns]

# %%
df_virginia_unsolved.iloc[:, 40:].head()
# Out:
#        Predicted_VictimOffenderRelationship  Prob_Acquaintance  \
# 845735                         Acquaintance               46.0
# 848941                         Acquaintance               53.0
# 849388                         Acquaintance               57.0
# 849908                         Acquaintance               48.0
# 850937                         Acquaintance               62.0
#
#         Prob_Boyfriend  Prob_Brother  Prob_Common-law husband  \
# 845735             0.0           3.0                      0.0
# 848941             6.0           4.0                      0.0
# 849388             2.0           1.0                      0.0
# 849908             2.0           2.0                      0.0
# 850937             1.0           0.0                      0.0
#
#         Prob_Common-law wife  Prob_Daughter  Prob_Employee  Prob_Employer  \
# 845735                   0.0            0.0            2.0            0.0
# 848941                   0.0            0.0            1.0            0.0
# 849388                   0.0            0.0            6.0            0.0
# 849908                   0.0            0.0            0.0            0.0
# 850937                   0.0            0.0            0.0            0.0
#
#         Prob_Ex-husband  ...  Prob_Other - known to victim  Prob_Other family  \
# 845735              0.0  ...                          39.0                1.0
# 848941              0.0  ...                           5.0                0.0
# 849388              0.0  ...                           2.0                1.0
# 849908              0.0  ...                           0.0                0.0
# 850937              0.0  ...                           0.0                0.0
#
#         Prob_Sister  Prob_Son  Prob_Stepdaughter  Prob_Stepfather  \
# 845735          0.0       0.0                0.0              0.0
# 848941          0.0       0.0                0.0              1.0
# 849388          0.0       1.0                0.0              0.0
# 849908          0.0       0.0                0.0              2.0
# 850937          0.0       0.0                0.0              0.0
#
#         Prob_Stepmother  Prob_Stepson  Prob_Stranger  Prob_Wife
# 845735              0.0           0.0            1.0        0.0
# 848941              0.0           0.0           17.0        0.0
# 849388              0.0           1.0           18.0        0.0
# 849908              0.0           0.0           27.0        0.0
# 850937              0.0           0.0           15.0        5.0
#
# [5 rows x 29 columns]

# %%
df_virginia_unsolved['Predicted_VictimOffenderRelationship'].value_counts()
# Out:
# Predicted_VictimOffenderRelationship
# Acquaintance               32
# Girlfriend                  2
# Son                         1
# Other - known to victim     1
# Stranger                    1
# Name: count, dtype: int64

# %% [markdown]
# # Using geopy to geolocate the county names of the unsolved cases and visualize the suspect demographics

# %%
import time
import folium

county_coords = {
    'Norfolk, VA': (36.8508, -76.2859),
    'Newport News, VA': (37.0871, -76.4730),
    'Prince William, VA': (38.7839, -77.6078),
    'Westmoreland, VA': (38.0938, -76.7981),
    'Alexandria, VA': (38.8048, -77.0469),
    'Richmond, VA': (37.5407, -77.4360),
    'Mecklenburg, VA': (36.6518, -78.3647),
    'Loudoun, VA': (39.0768, -77.6536),
    'Henrico, VA': (37.5056, -77.3320),
    'Hanover, VA': (37.7677, -77.3702),
    'Gloucester, VA': (37.4088, -76.5257),
    'Amherst, VA': (37.5859, -79.1097),
    'Hampton, VA': (37.0299, -76.3452),
    'Roanoke, VA': (37.2709, -79.9414)
}

df_virginia_unsolved['Coordinates'] = df_virginia_unsolved['CountyFIPS'].map(county_coords)
df_virginia_unsolved['Latitude'] = df_virginia_unsolved['Coordinates'].apply(lambda x: x[0] if pd.notnull(x) else None)
df_virginia_unsolved['Longitude'] = df_virginia_unsolved['Coordinates'].apply(lambda x: x[1] if pd.notnull(x) else None)

race_color = {
    'Black':'black',
    'White':'white',
    'Asian':'orange',
    'American India or Alaskan Native':'red'
}

m = folium.Map(location=[37.5, -78.7], zoom_start=7)
race_color = {
    'Black': 'black',
    'White': 'pink',
    'Asian': 'orange',
    'American Indian or Alaskan Native': 'red',
}


for idx, row in df_virginia_unsolved.iterrows():
    if pd.isnull(row['Latitude']) or pd.isnull(row['Longitude']):
        continue

    color = race_color.get(row['Predicted_OffenderRace'], 'gray')
    icon_type = 'male' if row['Predicted_OffenderSex'] == 'Male' else 'female'
    age = row['Predicted_AgeGroup']

    popup_text = (
        f"<b>Sex:</b> {row['Predicted_OffenderSex']}<br>"
        f"<b>Race:</b> {row['Predicted_OffenderRace']}<br>"
        f"<b>Age Group:</b> {age}<br>"
        f"<b>Victim Offender Relationship:</b> {row['Predicted_VictimOffenderRelationship']}"
    )

    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup_text,
        icon=folium.Icon(color=color, icon=icon_type, prefix='fa')
    ).add_to(m)

m.save('virginia_predicted_offenders_map.html')

# %% [markdown]
# # Final HTML map that showcases the distribution of the unsolved cases across Virginia, as well as popups containing relevant demographic information regarding each potential suspect

# %% [markdown]
# - Pink: White
# - Black: African American
# - Orange: Asian
# - Red: American Indian

# %%
from IPython.display import Image, display

display(Image('Demographic_Map.png'))

# %% [markdown]
# # Visualizing results of the predicted demographic

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Configuration ---
bar_color = '#7998A9'  # Single color for all charts
bar_width = 0.6

# --- Prepare data ---

# Group 1: Offender Sex
sex_counts = df_virginia_unsolved['Predicted_OffenderSex'].value_counts().sort_values(ascending=True)

# Group 2: Offender Race
race_counts = df_virginia_unsolved['Predicted_OffenderRace'].value_counts().sort_values(ascending=True)

# Group 3: Offender Age Group
agegroup_order = ['0-4', '5-12', '13-17', '18-24', '25-34', '35-49', '50-64', '65+']
age_counts = df_virginia_unsolved['Predicted_AgeGroup'].value_counts().reindex(agegroup_order).dropna()

# Group 4: Victim-Offender Relationship
relationship_counts = df_virginia_unsolved['Predicted_VictimOffenderRelationship'].value_counts().sort_values(ascending=True)

# --- Plotting ---

plt.figure(figsize=(18, 12))
plt.tight_layout()
plt.subplots_adjust(top=0.88)

# Main Title and Footer
plt.suptitle("Distribution of Predicted Offender Demographics and Relationship", fontsize=18, fontweight='bold', x=0.0, ha='left')
plt.figtext(0.0, 0.93, "Analyzing predicted demographic categories for unsolved offender profiles in Virginia", fontsize=13, ha='left')
plt.figtext(0.0, 0.05, "Each bar length represents number of predicted cases in each category.", fontsize=11, color='grey', ha='left')

# --- Subplot 1: Predicted Offender Sex ---
ax1 = plt.subplot(2, 2, 1)
y1 = np.arange(len(sex_counts))
ax1.barh(y1, sex_counts.values, color=bar_color)
ax1.set_yticks(y1)
ax1.set_yticklabels(sex_counts.index, fontsize=11)
ax1.set_title('Predicted Offender Sex', fontsize=14, fontweight='bold', loc='left')
ax1.grid(axis='x', linestyle='--', color='lightgrey')

# --- Subplot 2: Predicted Offender Race ---
ax2 = plt.subplot(2, 2, 2)
y2 = np.arange(len(race_counts))
ax2.barh(y2, race_counts.values, color=bar_color)
ax2.set_yticks(y2)
ax2.set_yticklabels(race_counts.index, fontsize=11)
ax2.set_title('Predicted Offender Race', fontsize=14, fontweight='bold', loc='left')
ax2.grid(axis='x', linestyle='--', color='lightgrey')

# --- Subplot 3: Predicted Offender Age Group ---
ax3 = plt.subplot(2, 2, 3)
y3 = np.arange(len(age_counts))
ax3.barh(y3, age_counts.values, color=bar_color)
ax3.set_yticks(y3)
ax3.set_yticklabels(age_counts.index, fontsize=11)
ax3.set_title('Predicted Offender Age Group', fontsize=14, fontweight='bold', loc='left')
ax3.grid(axis='x', linestyle='--', color='lightgrey')

# --- Subplot 4: Predicted Victim-Offender Relationship ---
ax4 = plt.subplot(2, 2, 4)
y4 = np.arange(len(relationship_counts))
ax4.barh(y4, relationship_counts.values, color=bar_color)
ax4.set_yticks(y4)
ax4.set_yticklabels(relationship_counts.index, fontsize=11)
ax4.set_title('Predicted Victim-Offender Relationship', fontsize=14, fontweight='bold', loc='left')
ax4.grid(axis='x', linestyle='--', color='lightgrey')

# --- Style all plots ---
for ax in [ax1, ax2, ax3, ax4]:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

plt.show()
